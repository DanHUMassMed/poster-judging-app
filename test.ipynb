# %%
import pandas as pd

df = pd.read_csv(
    "./data/poster-details.csv",
    parse_dates=["Date"]
)

# First try parsing with your main format
df['Date_parsed'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')

# # For unparsed rows, try alternative format
# mask = df['Date_parsed'].isna()
# df.loc[mask, 'Date_parsed'] = pd.to_datetime(df.loc[mask, 'Date'], format='%d/%m/%Y', errors='coerce')
# Out:
# /var/folders/jq/7cv336vx66v_c3vj7vwrpt6c0000gn/T/ipykernel_73480/1462948597.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(

# %%
#df

# %%
posters_df = pd.read_csv("./data/poster-details.csv", parse_dates=["Date"])
#posters_df['Date'] = pd.to_datetime(posters_df['Date'], format='%m/%d/%Y')

posters_df = posters_df.sort_values(by=['Date', 'Name']).reset_index(drop=True)
#return posters_df.to_dict(orient="records")
posters_df
# Out:
# /var/folders/jq/7cv336vx66v_c3vj7vwrpt6c0000gn/T/ipykernel_73480/2253287002.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   posters_df = pd.read_csv("./data/poster-details.csv", parse_dates=["Date"])
#     Poster_Id       Date    Session                     Name  \
# 0           1 2025-07-28     Monday          Adebayo, Daniel
# 1           6 2025-07-28     Monday      Anderson, Ruthellen
# 2           7 2025-07-28     Monday          Baird, Michelle
# 3           8 2025-07-28     Monday            Barger, Sarah
# 4          40 2025-07-28     Monday          Bettinger, Jill
# 5           2 2025-07-28     Monday           Bostrom, Emily
# 6           3 2025-07-28     Monday         Chadwick, Stormi
# 7           9 2025-07-28     Monday         Czerniak, Tomasz
# 8           4 2025-07-28     Monday   Demmitt-Rice, Courtney
# ...
